# %%
1a
START
INPUT item
INPUT price
INPUT total
INPUT change
INPUT payment
LET total = 0
FOR item
COMPUTE total = total + price
END FOR
IF payment >=total
COMPUTE change= payment - total
ELSE
DISPLAY "insufficient payment"
END IF
END

# %%
1b
START
INPUT Dave, 15
INPUT Sam, 18
temp = 15
15 = 18
18 = temp
PRINT Dave 15
PRINT Sam, 18
END
